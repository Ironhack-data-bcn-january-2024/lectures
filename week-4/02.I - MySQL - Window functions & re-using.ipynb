# %%
# queries

# queries on queries
    # subqueries
    # CTE: with statements (common-table-expressions)


# window functions
    # see aggregaeted functions without having aggregate: entire row AND the aggregation

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SQL-&amp;-Python" data-toc-modified-id="SQL-&amp;-Python-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SQL &amp; Python</a></span></li><li><span><a href="#Window-Functions" data-toc-modified-id="Window-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Window Functions</a></span></li><li><span><a href="#Aggregate-Functions:" data-toc-modified-id="Aggregate-Functions:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Aggregate Functions:</a></span><ul class="toc-item"><li><span><a href="#SUM-()" data-toc-modified-id="SUM-()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>SUM ()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-3.1.0.2"><span class="toc-item-num">3.1.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#AVG-()" data-toc-modified-id="AVG-()-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>AVG ()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-3.2.0.1"><span class="toc-item-num">3.2.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-3.2.0.2"><span class="toc-item-num">3.2.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#COUNT()" data-toc-modified-id="COUNT()-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>COUNT()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-3.3.0.1"><span class="toc-item-num">3.3.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-3.3.0.2"><span class="toc-item-num">3.3.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#MIN-()" data-toc-modified-id="MIN-()-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>MIN ()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-3.4.0.1"><span class="toc-item-num">3.4.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-3.4.0.2"><span class="toc-item-num">3.4.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#MAX()" data-toc-modified-id="MAX()-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>MAX()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-3.5.0.1"><span class="toc-item-num">3.5.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#Result-set" data-toc-modified-id="Result-set-3.5.0.2"><span class="toc-item-num">3.5.0.2&nbsp;&nbsp;</span>Result set</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Ranking-Functions" data-toc-modified-id="Ranking-Functions-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Ranking Functions</a></span><ul class="toc-item"><li><span><a href="#Rank()" data-toc-modified-id="Rank()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Rank()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-4.1.0.1"><span class="toc-item-num">4.1.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-4.1.0.2"><span class="toc-item-num">4.1.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#Dense_rank()" data-toc-modified-id="Dense_rank()-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Dense_rank()</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-4.2.0.1"><span class="toc-item-num">4.2.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-4.2.0.2"><span class="toc-item-num">4.2.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#ROW_NUMBER" data-toc-modified-id="ROW_NUMBER-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>ROW_NUMBER</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-4.3.0.1"><span class="toc-item-num">4.3.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-4.3.0.2"><span class="toc-item-num">4.3.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Analytic-Functions" data-toc-modified-id="Analytic-Functions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Analytic Functions</a></span><ul class="toc-item"><li><span><a href="#LEAD" data-toc-modified-id="LEAD-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>LEAD</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-5.1.0.1"><span class="toc-item-num">5.1.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-5.1.0.2"><span class="toc-item-num">5.1.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#LAG" data-toc-modified-id="LAG-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>LAG</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-5.2.0.1"><span class="toc-item-num">5.2.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-5.2.0.2"><span class="toc-item-num">5.2.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#FIRST_VALUE" data-toc-modified-id="FIRST_VALUE-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>FIRST_VALUE</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-5.3.0.1"><span class="toc-item-num">5.3.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-5.3.0.2"><span class="toc-item-num">5.3.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li><li><span><a href="#LAST_VALUE" data-toc-modified-id="LAST_VALUE-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>LAST_VALUE</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Initial-table" data-toc-modified-id="1.-Initial-table-5.4.0.1"><span class="toc-item-num">5.4.0.1&nbsp;&nbsp;</span>1. Initial table</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-5.4.0.2"><span class="toc-item-num">5.4.0.2&nbsp;&nbsp;</span>3. Result set</a></span></li><li><span><a href="#3.-Result-set" data-toc-modified-id="3.-Result-set-5.4.0.3"><span class="toc-item-num">5.4.0.3&nbsp;&nbsp;</span>3. Result set</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Re-using-code-&amp;-saving-processing-power" data-toc-modified-id="Re-using-code-&amp;-saving-processing-power-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Re-using code &amp; saving processing power</a></span><ul class="toc-item"><li><span><a href="#Temporary-Tables" data-toc-modified-id="Temporary-Tables-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Temporary Tables</a></span></li><li><span><a href="#Views" data-toc-modified-id="Views-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Views</a></span></li><li><span><a href="#Advanced:-procedures" data-toc-modified-id="Advanced:-procedures-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Advanced: procedures</a></span></li></ul></li><li><span><a href="#Extra" data-toc-modified-id="Extra-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Extra</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#From-the-Ravit-Show" data-toc-modified-id="From-the-Ravit-Show-7.0.0.1"><span class="toc-item-num">7.0.0.1&nbsp;&nbsp;</span>From the Ravit Show</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#YOUR-TURN" data-toc-modified-id="YOUR-TURN-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>YOUR TURN</a></span></li></ul></div>

# %% [markdown]
# ![friends](https://i0.wp.com/brightestyoungthings.com/wp-content/uploads/2017/10/best-friends-gif.gif?fit=480%2C294&quality=100&ssl=1)

# %% [markdown]
# # SQL & Python

# %%
import pymysql
import sqlalchemy as alch
from getpass import getpass
import pandas as pd

# %% [markdown]
# ```python
# def connection (dbName):
#     password = getpass()
#     connectionData=f"mysql+pymysql://root:{password}@localhost/{dbName}"
#
#     engine = alch.create_engine(connectionData)
#     return engine
#
# engine = connection ("publications")
#
# def simple_query (table, engine):
#     return pd.read_sql_query(f"""SELECT * FROM {table}""", engine)
#
# df = simple_query ("authors", engine)
# df
# ```

# %% [markdown]
# # Window Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These functions provide powerful tools for analyzing and processing data within specific partitions or frames, enabling advanced analytics and reporting capabilities in MySQL.
#
# To use window functions in MySQL, you typically include the function along with the OVER() clause, which defines the partitioning, ordering, and window frame for the function. This allows you to calculate aggregates, rankings, and other analytical insights over specific groups of rows in the result set.

# %% [markdown]
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# # Aggregate Functions:

# %% [markdown]
# - `SUM()`: Calculates the sum of a specified column over a defined window.
# - `AVG()`: Computes the average of a specified column within a given window.
# - `COUNT()`: Counts the number of rows in a specified window.
# - `MIN()`: Finds the minimum value in a specified column over a window.
# - `MAX()`: Finds the maximum value in a specified column over a window.

# %% [markdown]
# ```sql
# SELECT
#     Product,
#     Amount,
#     SUM(Amount) OVER () AS TotalSales,
#     AVG(Amount) OVER () AS AvgSales,
#     COUNT(*) OVER () AS TotalRows,
#     MIN(Amount) OVER () AS MinSale,
#     MAX(Amount) OVER () AS MaxSale
# FROM
#     Sales;
# ```

# %% [markdown]
# ## SUM ()

# %% [markdown]
# The sum(Amount) OVER (PARTITION BY Product) calculates the SUM sale amount for each product, giving the same SUM value for all rows within each product's partition

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set

# %% [markdown]
# ## AVG ()

# %% [markdown]
# The AVG(Amount) function calculates the overall average sale amount across all rows in the Sales table. In this case, the overall average sale amount is 150 based on the dummy data provided.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Product, Amount,
# AVG(Amount) OVER (Partition by Product) as average
# FROM sales;
#
#   ```

# %% [markdown]
# #### 3. Result set

# %% [markdown]
# ## COUNT()

# %% [markdown]
# The COUNT(*) OVER (PARTITION BY Product) function calculates the count of sales for each product, giving the same count for all rows within each product's partition.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Product, Amount,
# COUNT(product) OVER (partition by product) as count
# FROM sales;
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | SalesCountByProduct |
# |---------|--------|---------------------|
# | A       | 100    | 2                   |
# | A       | 200    | 2                   |
# | B       | 150    | 2                   |
# | B       | 180    | 2                   |
# | C       | 120    | 1                   |

# %% [markdown]
# ## MIN ()

# %% [markdown]
# The MIN(Amount) OVER (PARTITION BY Product) function calculates the minimum sale amount for each product, giving the same minimum value for all rows within each product's partition.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Product, Amount,
# MIN(Amount) OVER (Partition by Product) as the_min
# -- Groupby: categorical
# -- Agg: numerical
# -- *
# FROM sales;
#
#   ```

# %% [markdown]
# ```sql
#
# -- Q: Partition by many categorical
# -- A: https://stackoverflow.com/questions/33011523/how-to-use-multiple-columns-in-partition-by-and-ensure-no-duplicate-row-is-retur
# SELECT * FROM (
#             SELECT
#                 [Code],
#                 [Name],
#                 [CategoryCode],
#                 [CreatedDate],
#                 [ModifiedDate],
#                 [CreatedBy],
#                 [ModifiedBy],
#                 [IsActive],
#                 ROW_NUMBER() OVER(PARTITION BY [Code],[Name],[CategoryCode] ORDER BY ID DESC) rownumber
#             FROM MasterTable
#           ) a
#         WHERE rownumber = 1
#
# ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | MinSaleByProduct |
# |---------|--------|------------------|
# | A       | 100    | 100              |
# | A       | 200    | 100              |
# | B       | 150    | 150              |
# | B       | 180    | 150              |
# | C       | 120    | 120              |

# %% [markdown]
# The MIN(Amount) OVER (PARTITION BY Product) function calculates the minimum sale amount for each product, giving the same minimum value for all rows within each product's partition.

# %% [markdown]
# ## MAX()

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Region, Product, Amount,
# MAX(Amount) OVER (Partition by Product)
# as the_max
# FROM sales;
#
#   ```

# %% [markdown]
# #### Result set
#
# | Product | Amount | MaxSaleByProduct |
# |---------|--------|------------------|
# | A       | 100    | 200              |
# | A       | 200    | 200              |
# | B       | 150    | 180              |
# | B       | 180    | 180              |
# | C       | 120    | 120              |

# %% [markdown]
# # Ranking Functions

# %% [markdown]
# - `RANK()`: Assigns a rank to each row within a window based on specified criteria.
# - `DENSE_RANK()`: Assigns a dense rank (no gaps) to each row in a window.
# - `ROW_NUMBER()`: Assigns a unique number to each row within a window.

# %% [markdown]
# ```sql
# SELECT
#     Product,
#     Amount,
#     RANK() OVER (ORDER BY Amount DESC) AS RankByAmount,
#     DENSE_RANK() OVER (ORDER BY Amount DESC) AS DenseRankByAmount,
#     ROW_NUMBER() OVER (ORDER BY Amount DESC) AS RowNumberByAmount
# FROM
#     Sales;
# ```

# %% [markdown]
# ## Rank()

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | SalesRank |
# |---------|--------|-----------|
# | A       | 200    | 1         |
# | B       | 180    | 2         |
# | B       | 150    | 3         |
# | C       | 120    | 4         |
# | A       | 100    | 5         |

# %% [markdown]
# ## Dense_rank()

# %% [markdown]
# The DENSE_RANK() function, similar to RANK(), assigns a rank to each row based on the Amount. However, unlike RANK(), it does not leave gaps between the ranks in case of ties; it provides a consecutive rank to each row based on the ordering criteria. In this case, the highest sales amount gets rank 1, the second highest gets rank 2, and so on, without any gaps.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | DenseSalesRank |
# |---------|--------|----------------|
# | A       | 200    | 1              |
# | B       | 180    | 2              |
# | B       | 150    | 3              |
# | C       | 120    | 4              |
# | A       | 100    | 5              |

# %% [markdown]
# ## ROW_NUMBER

# %% [markdown]
# The ROW_NUMBER() function assigns a unique number to each row based on the Amount, without any gaps. The row with the highest sales amount is assigned the number 1, the second highest gets 2, and so on.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | RowNumberByAmount |
# |---------|--------|-------------------|
# | A       | 200    | 1                 |
# | B       | 180    | 2                 |
# | B       | 150    | 3                 |
# | C       | 120    | 4                 |
# | A       | 100    | 5                 |

# %% [markdown]
# # Analytic Functions

# %% [markdown]
# - `LEAD():` Accesses data from subsequent rows within a window.
# - `LAG():` Accesses data from preceding rows within a window.
# - `FIRST_VALUE():` Returns the first value in a window based on the specified order.
# - `LAST_VALUE():` Returns the last value in a window based on the specified order.

# %% [markdown]
# ```sql
# SELECT
#     Product,
#     Amount,
#     LEAD(Amount) OVER (ORDER BY Amount) AS NextSaleAmount,
#     LAG(Amount) OVER (ORDER BY Amount) AS PrevSaleAmount,
#     FIRST_VALUE(Amount) OVER (PARTITIOM BY Amount) AS FirstSaleAmount,
#     LAST_VALUE(Amount) OVER (PARTITION BY Amount) AS LastSaleAmount
# FROM
#     Sales;
# ```

# %% [markdown]
# ## LEAD

# %% [markdown]
# The LEAD() function retrieves the amount of the next sale for each product, based on the ordering by amount within each product's partition. For the last sale of each product, where there is no "next" sale, LEAD() returns NULL.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Product, Amount,
# LAG(Amount) OVER (ORDER BY Amount) as the_lead,
# amount - LAG(Amount) OVER (ORDER BY Amount) as dif
# from sales
# ORDER BY PRODUCT ASC;
# -- A changes more than B
# -- C there's only one
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | NextSaleAmount |
# |---------|--------|----------------|
# | A       | 200    | 100            |
# | A       | 100    | NULL           |
# | B       | 180    | 150            |
# | B       | 150    | NULL           |
# | C       | 120    | NULL           |

# %% [markdown]
# ## LAG

# %% [markdown]
# The LAG() function retrieves the amount of the previous sale for each product, based on the ordering by amount within each product's partition. For the first sale of each product, where there is no "previous" sale, LAG() returns NULL.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | PreviousSaleAmount |
# |---------|--------|--------------------|
# | A       | 200    | NULL               |
# | A       | 100    | 200                |
# | B       | 180    | NULL               |
# | B       | 150    | 180                |
# | C       | 120    | NULL               |

# %% [markdown]
# ## FIRST_VALUE

# %% [markdown]
# The FIRST_VALUE() function retrieves the amount of the first sale for each product, based on the ordering by amount within each product's partition. It provides the same value for all rows within each partition.

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set
#
# | Product | Amount | FirstSaleAmount |
# |---------|--------|-----------------|
# | A       | 100    | 100             |
# | A       | 200    | 100             |
# | B       | 150    | 150             |
# | B       | 180    | 150             |
# | C       | 120    | 120             |

# %% [markdown]
# ## LAST_VALUE

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 1. Initial table
#
# | Product | Amount | Region   |
# |---------|--------|----------|
# | A       | 100    | North    |
# | B       | 150    | South    |
# | A       | 200    | East     |
# | C       | 120    | West     |
# | B       | 180    | Central  |

# %% [markdown]
# ```sql
# -- 2. Query
# SELECT Product, Amount,
# LAST_VALUE(Amount) OVER (PARTITION BY Product)
#  AS LastSaleAmpount
# FROM sales;
# -- What is the latest value for amount
# -- Amount for the last value for each category?
#
# ```

# %% [markdown]
# ```sql
# SELECT Product, Amount,
# LAST_VALUE(Amount) OVER (PARTITION BY Product)
#  AS LastSaleAmpount,
# amount - LAST_VALUE(Amount) OVER (PARTITION BY Product) as dif
# FROM sales
# order by dif DESC;
#
# ```

# %%
# Do: Aggregations
# Show: non-aggreated values & the aggregated

FUNCTION()
    OVER ()
        PARTITION BY: categories
        ORDER BY: numerical

# Create new columns on the side (it doesn't create them)
            
SELECT RANK() OVER(ORDER BY amount desc) ...

# %% [markdown]
# #### 3. Result set

# %% [markdown]
# - `NTILE():` Divides the result set into a specified number of buckets and assigns a unique identifier to each.

# %% [markdown]
# The NTILE(4) function divides the sales into 4 quartiles based on the Amount, assigning a quartile number to each row. The quartile numbers range from 1 to 4, representing the respective quartile each sale falls into based on its amount.

# %% [markdown]
# ```sql
# -- 2. Query
#
#   ```

# %% [markdown]
# #### 3. Result set
#
#
# | Product | Amount | Quartile |
# |---------|--------|----------|
# | A       | 100    | 1        |
# | C       | 120    | 1        |
# | B       | 150    | 2        |
# | B       | 180    | 3        |
# | A       | 200    | 4        |

# %% [markdown]
# # Re-using code & saving processing power

# %% [markdown]
# - Temporary tables
# - Views
# - Advanced: Procedures

# %% [markdown]
# ## Temporary Tables

# %% [markdown]
# Temporary tables are staging tables that are built from the results of queries and dropped after the database session has ended. They serve to store the results of the query for later use in the session. The way to avoid having to write the same subquery multiple times is to save the query results to a temporary table and then query the temporary table each time we need to access those results.
#
# Let's see how we could have changed the subquery from the previous section to a temporary table. To do this, we can use the CREATE TEMPORARY TABLE command, followed by the name we want to give the new table and the query.

# %%
# temp table:
    # temporary: connection 
        # it will exist as long as im connected

# %% [markdown]
# ```sql
# create temporary table summary
# SELECT stor_name, Items/Orders as avgItems, Quantity/Items as avgQty
# FROM
#         (SELECT stores.stor_name, COUNT(DISTINCT(ord_num)) as Orders,
#              COUNT(qty) as Items, SUM(qty) as Quantity
#             FROM sales
#                 JOIN stores
#                     ON sales.stor_id = stores.stor_id
#                 GROUP BY stores.stor_name
#                 ORDER BY Quantity DESC)
# as ola;
#
# select * from summary;
# ```

# %% [markdown]
# ## Views

# %% [markdown]
# ```sql
# CREATE VIEW the_vieeeeewwww AS
# SELECT stor_name, Items/Orders as avgItems, Quantity/Items as avgQty
# FROM
#
#         (SELECT stores.stor_name, COUNT(DISTINCT(ord_num)) as Orders,
#              COUNT(qty) as Items, SUM(qty) as Quantity
#             FROM sales
#                 JOIN stores
#                     ON sales.stor_id = stores.stor_id
#                 GROUP BY stores.stor_name
#                 ORDER BY Quantity DESC)
#
#         as summary;
# ```

# %% [markdown]
# ## Advanced: procedures

# %% [markdown]
# ```sql
# DELIMITER //
# CREATE PROCEDURE get_someone_id_int(IN theid INT)
#     BEGIN
#
#     	SELECT * FROM employees
#     		WHERE id = theid;
#
#     END //
#
# DELIMITER ;
# ```

# %% [markdown]
# ```sql
# -- function with two arguments
# DELIMITER //
# CREATE PROCEDURE get_someone_id_int_2(IN theid INT, IN thename VARCHAR(10))
#     BEGIN
#
#         SELECT * FROM employees
#             WHERE id = theid
#             and fullname = thename;
#
#     END //
#
# DELIMITER ;
# ```

# %% [markdown]
# ![Screenshot%202022-07-25%20at%2022.10.17.png](attachment:Screenshot%202022-07-25%20at%2022.10.17.png)

# %% [markdown]
# # Extra

# %% [markdown]
# #### From the Ravit Show

# %% [markdown]
# ![Screenshot%202022-11-03%20at%2015.30.26.png](attachment:Screenshot%202022-11-03%20at%2015.30.26.png)

# %% [markdown]
# `SQL flavors`

# %% [markdown]
# - MySQL vs PostgreSQL: "", ``

# %% [markdown]
# # YOUR TURN
# What did we learn today?

# %%
# RECAP SQL

# language for relational databases
# Tables
    # primary keys: column with unique values that identifies a row
    # foreign keys: a column in a table that is a PK in another one. can be repeated

# Joins
    # left: info from the left always will be there, right, maybe?
    # inner: No null values: both in both tables
    # the rest: outer, right, self-join,...

# Queries
    # group by, order by, limit, ...
    # having & where
    # regexp, date functions,...
    
# Subqueries
    # executed first
    # work on its own
    # Result 1: (row1, row2, row3,...)
        # where something IN
        # where something = ...
        
    # Result 2: table
        # from
        # every derived table must have its own alias (AS ola;)
        
    
# CTE, common-table-expressions, WITH statements
    # to create sub tables
    # like subqueries, but more comofrotable
    # they create a "temporary table" within the query
    
# Window functions: select SUM(Amopunt) over (parition by Product DESC)
    # Return un-aggrated info with it's aggregation on the side
    # It'll take a subset of rows (window) and will pass a function (sum) to it
    # Aggregation (sum, count, avg)
    # Analytics: lead, lag, first_value, last_value
    # RANK
    # NTILE...
    # Description of the iunfo while having the info as well

# Temporary tables
    # within the connection
    # they are dropped right after
    # they are the result of a query
    
# VIEWS
    # within the schema
    # the result of a query
    # as reporting, for access control
    # it's dynamic: updated as the persistant tables are updated
    
# Procedures
    # functions
    # it takes arguments
    # they are saved
