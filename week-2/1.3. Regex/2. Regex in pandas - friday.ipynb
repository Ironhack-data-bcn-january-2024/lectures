# %%
# week-2/1.3. Regex
# Out:
# /Users/fernandocosta/IRONHACK/lectures/week-2/1.3. Regex

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %% [markdown]
# # Extract

# %% [markdown]
# `1. Extract the links`

# %%
df = pd.DataFrame({'text': ['Visit our website at https://example.com', 'For more information, go to http://www.example.org']})
df
# Out:
#                                                 text
# 0           Visit our website at https://example.com
# 1  For more information, go to http://www.example...

# %% [markdown]
# `pattern_link = "?"`

# %%
pattern_link =

# %% [markdown]
# `2. Extract the phone_number`

# %%
df = pd.DataFrame({'text': ['Call me at (123) 456-7890 or 555-5555', 'No phone numbers here']})
df
# Out:
#                                     text
# 0  Call me at (123) 456-7890 or 555-5555
# 1                  No phone numbers here

# %% [markdown]
# `pattern_phone = "(\(\d{1,4}\)\s\d{3}-\d{4})[\sa-z]+(\d{3}-\d{4})"`

# %% [markdown]
# `3. Extract the email`

# %%
df = pd.DataFrame(data = {'text': ['Send an email to john@example.com or mary@gmail.com', 'Contact support at support@example.org']})
df

# %% [markdown]
# `pattern_email = "?"`

# %% [markdown]
# `4. Extract the names and exapnd the columns`

# %% [markdown]
# `pattern_names = "?"`

# %% [markdown]
# # Replace

# %% [markdown]
# `1. Remove non-alphanumeric`

# %%
df = pd.DataFrame({'text': ['Hello, World!', 'This is a test...']})
df
# Out:
#                 text
# 0      Hello, World!
# 1  This is a test...

# %% [markdown]
# `patter_non_alphanumeric = "\W+"`
