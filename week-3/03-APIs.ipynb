# %% [markdown]
# # APIS

# %% [markdown]
# ![apis_gif](https://media.giphy.com/media/wepUQluC5smgEd4Qz4/giphy.gif)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries-summary" data-toc-modified-id="Libraries-summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries summary</a></span></li><li><span><a href="#Internet,-DNS,-IPs" data-toc-modified-id="Internet,-DNS,-IPs-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Internet, DNS, IPs</a></span></li><li><span><a href="#HTTP" data-toc-modified-id="HTTP-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>HTTP</a></span><ul class="toc-item"><li><span><a href="#URL" data-toc-modified-id="URL-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>URL</a></span></li><li><span><a href="#HTTP-vs-HTTPS" data-toc-modified-id="HTTP-vs-HTTPS-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>HTTP vs HTTPS</a></span></li><li><span><a href="#Requests" data-toc-modified-id="Requests-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Requests</a></span></li><li><span><a href="#Response" data-toc-modified-id="Response-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Response</a></span></li></ul></li><li><span><a href="#API" data-toc-modified-id="API-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>API</a></span><ul class="toc-item"><li><span><a href="#RESTful-APIs" data-toc-modified-id="RESTful-APIs-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>RESTful APIs</a></span></li></ul></li><li><span><a href="#Let's-go" data-toc-modified-id="Let's-go-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Let's go</a></span><ul class="toc-item"><li><span><a href="#Requests-in-Python" data-toc-modified-id="Requests-in-Python-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Requests in Python</a></span></li><li><span><a href="#HTML-response" data-toc-modified-id="HTML-response-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>HTML response</a></span></li><li><span><a href="#JSON-response" data-toc-modified-id="JSON-response-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>JSON response</a></span></li><li><span><a href="#Data-management-in-pandas" data-toc-modified-id="Data-management-in-pandas-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Data management in pandas</a></span></li><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Parameters</a></span></li></ul></li><li><span><a href="#It's-now-your-turn" data-toc-modified-id="It's-now-your-turn-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>It's now your turn</a></span></li><li><span><a href="#STEPS-TO-GET-REPONSES" data-toc-modified-id="STEPS-TO-GET-REPONSES-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>STEPS TO GET REPONSES</a></span></li><li><span><a href="#STEPS-TO-MANIPULATE-THE-RESPONSES" data-toc-modified-id="STEPS-TO-MANIPULATE-THE-RESPONSES-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>STEPS TO MANIPULATE THE RESPONSES</a></span></li><li><span><a href="#Headers" data-toc-modified-id="Headers-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Headers</a></span></li><li><span><a href="#API-Keys-/-tokens-/-private_keys" data-toc-modified-id="API-Keys-/-tokens-/-private_keys-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>API Keys / tokens / private_keys</a></span></li><li><span><a href="#API-Clients" data-toc-modified-id="API-Clients-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>API Clients</a></span><ul class="toc-item"><li><span><a href="#THIS-IS-FROM-RAPIDAPI--->-https://rapidapi.com/community/api/open-weather-map/" data-toc-modified-id="THIS-IS-FROM-RAPIDAPI--->-https://rapidapi.com/community/api/open-weather-map/-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>THIS IS FROM RAPIDAPI --&gt; <a href="https://rapidapi.com/community/api/open-weather-map/" rel="nofollow" target="_blank">https://rapidapi.com/community/api/open-weather-map/</a></a></span></li><li><span><a href="#Insomnia" data-toc-modified-id="Insomnia-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Insomnia</a></span></li><li><span><a href="#Codes-generated-by-insomnia" data-toc-modified-id="Codes-generated-by-insomnia-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Codes generated by insomnia</a></span></li></ul></li><li><span><a href="#Spotify" data-toc-modified-id="Spotify-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Spotify</a></span><ul class="toc-item"><li><span><a href="#Load-initial-credentials" data-toc-modified-id="Load-initial-credentials-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Load initial credentials</a></span></li><li><span><a href="#Get-token-from-those-initial-credentials" data-toc-modified-id="Get-token-from-those-initial-credentials-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Get token from those initial credentials</a></span></li><li><span><a href="#With-token,-we-can-create-the-headers" data-toc-modified-id="With-token,-we-can-create-the-headers-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>With token, we can create the headers</a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Summary</a></span></li><li><span><a href="#Further-materials" data-toc-modified-id="Further-materials-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Further materials</a></span></li></ul></div>

# %%
# a connection to a page
# to extract information
# they give you the path



# API: app Applications Program Interface
# middle man (intermediario) APP - APP

# user - API - database (website)
# table - waiter/server - kitchen

# REQUEST: "steak medium" - API (waiter) - kitchen (cook)
# RESULT: plate on your table 

# client ask (request) based on a menu (documentaiton) to a waiter (server / API)
    # that communicates with the cook (backend / database)

# Abstract yourself from architecture of someon's data
# you dont have the whole dataset
# you don't know the language used


# API are built by developers
     # they set their own rules
    
# it's a tool: you can use
    # because they allow you to use it

# %%
"""SELECT * FROM home"""

# %%
# 1. Request: https://www.murallasport.com/marcas

# 2. def request (url)
        # result = sql_query("""SELECT * FROM marcas;""")
        # return result
        
# 3. website with information about the marcas

# %%
# 1. Request: https://www.google.com/search?q=mumnich+shoes&oq=mumnich+shoes&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIHCAEQABiABDIHCAIQLhiABDIHCAMQABiABDIHCAQQABiABDIHCAUQABiABDIHCAYQABiABDIHCAcQLhiABDINCAgQLhjHARjRAxiABNIBCDE0NDZqMGo3qAIAsAIA&sourceid=chrome&ie=UTF-8

# 2. def request (url, search="munich shoes")
        # query = """select * from search_table WHERE input LIKE ("%MUNICH shoes") """
        # return query

# 3. website with information about the munich shoes: HTML document

# %%
# I don't know: how the data structure in google is
# I don't know: the access to the data
# I don't know anything
# I do know: how to ask

# %% [markdown]
# ## Libraries summary

# %%
import pandas as pd
from pandas import json_normalize

import requests 
import json
import os
from dotenv import load_dotenv #conda install -c conda-forge python-dotenv

import time

import sys
sys.path.append("../")

# %% [markdown]
# ## Internet, DNS, IPs

# %% [markdown]
# ![enjuto](https://www.publico.es/files/article_main/uploads//2014/12/13/548bb18f1d9ef.jpg)

# %% [markdown]
# - DNS (Domain Name Server): Maps the Internet address www.google.com to the server IP: 216.58.222.196
# - IP: server identification. code that allows information to be sent and received by the correct parties
# - Domain providers: they sell and buy Internet domains

# %% [markdown]
# ## HTTP

# %% [markdown]
# **H**yper **T**ext **T**transfer **P**rotocol
# HTTP is a communications protocol that provides a structure for requests between client and server on a network.
# For example, the web browser on the user's computer (the client) uses the HTTP protocol to request information from a website on a server.

# %% [markdown]
# ### URL
# Contains information about the resource that is being requested from the SERVER.
# Examples:
#
# - http://www.towardsdatascience.com
# - https://www.ironhack.com/
# - Protocol: https (https == http is the same but https is encrypted)
# - Domain name --> IRONHACK
# - TLD (top level domain) --> .com
# - https://www.google.com/webhp?authuser=2

# %% [markdown]
# ### HTTP vs HTTPS
#
# - HTTP transfers data in plain text while HTTPS transfers data in encrypted text.
# - HTTP is faster than HTTPS because the latter consumes computing power to encrypt the communication channel.

# %% [markdown]
# ### Requests

# %% [markdown]
# The **Requests** are questions that we ask a SERVER to receive information (a **response**).
# Types of request (verb):
# - GET: read the information from the resource, and do not modify it in any way. Accessing the web page from the browser **gets** information.
# - POST
# - PUT
# - DELETE
# - PATCH
# - ...

# %% [markdown]
# ### Response
# Responses can be of various types:
# * a JSON (similar to Python's dictionary)
# * an image
# * a video
# * an HTML page
# * a PDF file
# * ...

# %% [markdown]
# The responses follow the following structure. Have:
# - a HEADER section: contains metadata about the behavior of the server
# - a BODY: contains the desired information
#
# An important part of the HEADER is the **status code**. This code is a numeric code indicating the result of the server. There are different status codes depending on whether the server has succeeded in making the request or has failed to do anything. Here are some groups of status codes:
#
# - **2xx** successful__: the request was received, understood and accepted successfully
# - **3xx** redirect__: more action is needed to complete the request
# - **4xx** client error__: request contains incorrect syntax or cannot be fulfilled
# - **5xx** server error__: the server was unable to complete an apparently valid request
#
# Complete list:
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
#
# Much more fun:
# https://http.cat/

# %%
import requests
res = requests.get("https://www.jackjones.com/")
res
# Out:
# <Response [200]>

# %%
import json

# %%
list(res.headers.keys())
# Out:
# ['Connection',
#  'Content-Length',
#  'Content-Type',
#  'Access-Control-Allow-Headers',
#  'Cache-Control',
#  'Content-Encoding',
#  'X-Correlation-ID',
#  'Content-Security-Policy',
#  'X-Content-TypeOptions',
#  'X-Frame-Options',
#  'X-XSS-Protection',
#  'Accept-Ranges',
#  'Date',
#  'Via',
#  'X-Served-By',
#  'X-Cache',
#  'X-Cache-Hits',
#  'X-Timer',
#  'Vary',
#  'Strict-Transport-Security',
#  'alt-svc']

# %%
#res.content

# %% [markdown]
# ## API

# %% [markdown]
# **A**pplication **P**rogramming **I**nterface
# - In the cloud era, programs need to communicate over the Internet.
# - Within a project, the backend may want to share information with the frontend without access to the database.
# - It is a contract between software products.
# * It is an instruction manual to use a software.
# * The client calls the server through an API, the server responds.

# %% [markdown]
# ![API - Waiter](https://miro.medium.com/max/1400/0*2tmGZJKP6LfDycgV.png)

# %% [markdown]
# ### RESTful APIs

# %% [markdown]
# Most interactive APIs follow REST logic, a set of rules
# - [REST Guiding Principles](https://restfulapi.net/)
#
# Who does what:
# - We (client) send a request
# - They (server) return a response, usually in JSON format
#
# APIs always have to offer documentation of their different services: **endpoints**<br>
# Each endpoint is a different URL

# %% [markdown]
# ## Let's go

# %% [markdown]
# ### Requests in Python

# %% [markdown]
# https://requests.readthedocs.io/en/master/

# %%
#!pip install requests
#conda install requests

# %%
import requests

# %%
res = requests.get("https://elpais.com")
#res.content

# %% [markdown]
# ### HTML response

# %% [markdown]
# I can call a url and have all the html, all the response from the server.

# %%
res = requests.get("https://elpais.com")
#res.content

# %% [markdown]
# ### JSON response

# %% [markdown]
# JSON: Java Script Object Notation

# %% [markdown]
# Let's get information from the ISS (international space station)

# %% [markdown]
# [ISS API documentation](https://wheretheiss.at/w/developer)

# %%
res = requests.get("https://wheretheiss.at/").content
#res

# %%
url = "https://api.wheretheiss.at/v1/satellites"

# %% [markdown]
# If the Content-Type of the response is json, we can access it with `.json()`
# [Documentation](https://docs.python.org/3/library/json.html)

# %%
res = requests.get(url).json()
res # NOT HTML document
# Out:
# [{'name': 'iss', 'id': 25544}]

# %%
res[0]
# Out:
# {'name': 'iss', 'id': 25544}

# %%
res[0]["name"]
# Out:
# 'iss'

# %%
res[0]["id"]
# Out:
# 25544

# %%
# JSON library will PARSE the response
    # into a JSON shape (into a dictionary)

# %% [markdown]
# We make the call to the satellites endpoint with the id because it has already been returned to us by the previous request

# %%
id_satellite = res[0]["id"]
id_satellite
# Out:
# 25544

# %%
res = requests.get(f"https://api.wheretheiss.at/v1/satellites/{id_satellite}").json()
res
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': -24.606468842604,
#  'longitude': -40.345552632715,
#  'altitude': 426.50152167978,
#  'velocity': 27557.789091683,
#  'visibility': 'daylight',
#  'footprint': 4540.393477844,
#  'timestamp': 1706869242,
#  'daynum': 2460342.9310417,
#  'solar_lat': -16.895761122879,
#  'solar_lon': 28.230597317474,
#  'units': 'kilometers'}

# %%
import time

# %%
# json: stringified version of a dict_/object
    # dict_: python
    # object: javascript

# %%
# b'{}' -> json () -> dict_
# JSON: JavaScript Object (dict) Notation

# %%
new_list = []
for i in range(9):
    res = requests.get(f"https://api.wheretheiss.at/v1/satellites/{id_satellite}").json()
    new_list.append(res)
    time.sleep(2)
new_list
# Out:
# [{'name': 'iss',
#   'id': 25544,
#   'latitude': -16.257568555409,
#   'longitude': -33.215664308321,
#   'altitude': 423.94253928176,
#   'velocity': 27563.686977467,
#   'visibility': 'daylight',
#   'footprint': 4527.4671884492,
#   'timestamp': 1706869414,
#   'daynum': 2460342.9330324,
#   'solar_lat': -16.895187697783,
#   'solar_lon': 27.513993159069,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -16.15852946556,
#   'longitude': -33.137304042954,
#   'altitude': 423.9151850515,
#   'velocity': 27563.754235933,
#   'visibility': 'daylight',
#   'footprint': 4527.3287694285,
#   'timestamp': 1706869416,
#   'daynum': 2460342.9330556,
#   'solar_lat': -16.895181029968,
#   'solar_lon': 27.505660597335,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -16.009900210453,
#   'longitude': -33.019922447403,
#   'altitude': 423.87428034956,
#   'velocity': 27563.855026603,
#   'visibility': 'daylight',
#   'footprint': 4527.1217721048,
#   'timestamp': 1706869419,
#   'daynum': 2460342.9330903,
#   'solar_lat': -16.895171028112,
#   'solar_lon': 27.493161587088,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.861191393456,
#   'longitude': -32.902733051871,
#   'altitude': 423.83353000983,
#   'velocity': 27563.955695749,
#   'visibility': 'daylight',
#   'footprint': 4526.9155444388,
#   'timestamp': 1706869422,
#   'daynum': 2460342.933125,
#   'solar_lat': -16.895161026377,
#   'solar_lon': 27.480662744482,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.762007315286,
#   'longitude': -32.824711679117,
#   'altitude': 423.80644922218,
#   'velocity': 27564.022740579,
#   'visibility': 'daylight',
#   'footprint': 4526.7784887442,
#   'timestamp': 1706869424,
#   'daynum': 2460342.9331481,
#   'solar_lat': -16.895154358555,
#   'solar_lon': 27.472330182725,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.563530667665,
#   'longitude': -32.668916384255,
#   'altitude': 423.75249551351,
#   'velocity': 27564.156665394,
#   'visibility': 'daylight',
#   'footprint': 4526.505414267,
#   'timestamp': 1706869428,
#   'daynum': 2460342.9331944,
#   'solar_lat': -16.895141022766,
#   'solar_lon': 27.455664891597,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.414582529586,
#   'longitude': -32.552286604525,
#   'altitude': 423.7122145225,
#   'velocity': 27564.256959835,
#   'visibility': 'daylight',
#   'footprint': 4526.3015280423,
#   'timestamp': 1706869431,
#   'daynum': 2460342.9332292,
#   'solar_lat': -16.895131021018,
#   'solar_lon': 27.443166048964,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.315238381706,
#   'longitude': -32.474633355783,
#   'altitude': 423.68544827595,
#   'velocity': 27564.323752286,
#   'visibility': 'daylight',
#   'footprint': 4526.1660418354,
#   'timestamp': 1706869433,
#   'daynum': 2460342.9332523,
#   'solar_lat': -16.895124353048,
#   'solar_lon': 27.434833319584,
#   'units': 'kilometers'},
#  {'name': 'iss',
#   'id': 25544,
#   'latitude': -15.166160722152,
#   'longitude': -32.358306577633,
#   'altitude': 423.64543309909,
#   'velocity': 27564.423829442,
#   'visibility': 'daylight',
#   'footprint': 4525.9634825543,
#   'timestamp': 1706869436,
#   'daynum': 2460342.933287,
#   'solar_lat': -16.895114351292,
#   'solar_lon': 27.422334476936,
#   'units': 'kilometers'}]

# %%
df = pd.DataFrame(new_list)
df
# Out:
#   name     id   latitude  longitude    altitude      velocity visibility
# 0  iss  25544 -16.257569 -33.215664  423.942539  27563.686977   daylight  \
# 1  iss  25544 -16.158529 -33.137304  423.915185  27563.754236   daylight
# 2  iss  25544 -16.009900 -33.019922  423.874280  27563.855027   daylight
# 3  iss  25544 -15.861191 -32.902733  423.833530  27563.955696   daylight
# 4  iss  25544 -15.762007 -32.824712  423.806449  27564.022741   daylight
# 5  iss  25544 -15.563531 -32.668916  423.752496  27564.156665   daylight
# 6  iss  25544 -15.414583 -32.552287  423.712215  27564.256960   daylight
# 7  iss  25544 -15.315238 -32.474633  423.685448  27564.323752   daylight
# 8  iss  25544 -15.166161 -32.358307  423.645433  27564.423829   daylight
#
#      footprint   timestamp        daynum  solar_lat  solar_lon       units
# 0  4527.467188  1706869414  2.460343e+06 -16.895188  27.513993  kilometers
# 1  4527.328769  1706869416  2.460343e+06 -16.895181  27.505661  kilometers
# 2  4527.121772  1706869419  2.460343e+06 -16.895171  27.493162  kilometers
# 3  4526.915544  1706869422  2.460343e+06 -16.895161  27.480663  kilometers
# 4  4526.778489  1706869424  2.460343e+06 -16.895154  27.472330  kilometers
# 5  4526.505414  1706869428  2.460343e+06 -16.895141  27.455665  kilometers
# 6  4526.301528  1706869431  2.460343e+06 -16.895131  27.443166  kilometers
# 7  4526.166042  1706869433  2.460343e+06 -16.895124  27.434833  kilometers
# 8  4525.963483  1706869436  2.460343e+06 -16.895114  27.422334  kilometers

# %%
res = requests.get(f"https://api.wheretheiss.at/v1/satellites/{id_satellite}?units=miles").json()
res
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': 9.2930883391551,
#  'longitude': -14.688120454307,
#  'altitude': 260.92336977232,
#  'velocity': 17135.895245599,
#  'visibility': 'daylight',
#  'footprint': 2800.5402192401,
#  'timestamp': 1706869919,
#  'daynum': 2460342.9388773,
#  'solar_lat': -16.893503981916,
#  'solar_lon': 25.410009862797,
#  'units': 'miles'}

# %%
url = f"https://api.wheretheiss.at/v1/satellites/{id_satellite}"

params = {"units":"kilometers"}

res = requests.get(url, params=params).json()
res
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': 12.314925805154,
#  'longitude': -12.448334774044,
#  'altitude': 419.87102720817,
#  'velocity': 27578.655230056,
#  'visibility': 'daylight',
#  'footprint': 4506.8072466736,
#  'timestamp': 1706869979,
#  'daynum': 2460342.9395718,
#  'solar_lat': -16.893303925268,
#  'solar_lon': 25.16003165494,
#  'units': 'kilometers'}

# %%
# API: program
    # a program someone else built
    # it has rules: they need to tell us
    # sometimes the documentation will be well writte 
    
# Both websites & APIs return responses
    # www.google.com -> html
    # api link
        # MAY LOOK: api.website.com
        # may not look like api as a prefix
        
    # NOT ALL WEBSITES HAVE PUBLIC API's
    # APIS: return jsons (mostly)

# %%
#requests.get("https://www.google.es").json()
# JSONDecodeError  -> probably not querying the API but the the website

# %% [markdown]
# ### Data management in pandas

# %% [markdown]
# ### Parameters

# %% [markdown]
# Remember... The API Documentation
# https://wheretheiss.at/w/developer

# %% [markdown]
# ![captura](../images/parameters.png)

# %% [markdown]
# Sometimes we want to pass some parameters to an API endpoint.
# Similar to python functions receiving parameters for different behavior

# %% [markdown]
# Parameters are passed with `?param1=value1&param2=value2...` at the end of the URL

# %%
res = requests.get(f"https://api.wheretheiss.at/v1/satellites/{id_satellite}?units=miles").json()
res

# %% [markdown]
# The `requests` library lets pass the parameters as a dictionary

# %%
url = f"https://api.wheretheiss.at/v1/satellites/{id_satellite}"

params = {"units":"kilometers"}

res = requests.get(url, params=params).json()
res

# %% [markdown]
# ## It's now your turn

# %% [markdown]
# Check out this API... 👆or any other, [YOU CAN LOOK HERE](https://github.com/public-apis/public-apis) to do the exercise.
# Try to call an API, with or without parameters and... get some information!!

# %%
res = requests.get("https://cat-fact.herokuapp.com/facts").json()
res[0]
# Out:
# {'status': {'verified': True, 'sentCount': 1},
#  '_id': '58e00b5f0aac31001185ed24',
#  'user': '58e007480aac31001185ecef',
#  'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#  '__v': 0,
#  'source': 'user',
#  'updatedAt': '2020-08-23T20:20:01.611Z',
#  'type': 'cat',
#  'createdAt': '2018-02-19T21:20:03.434Z',
#  'deleted': False,
#  'used': False}

# %%
# Pol
import requests
url = "https://dogapi.dog/api/v2/breeds"
res = requests.get(url).json() 
res
# Out:
# {'data': [{'id': '68f47c5a-5115-47cd-9849-e45d3c378f12',
#    'type': 'breed',
#    'attributes': {'name': 'Caucasian Shepherd Dog',
#     'description': 'The Caucasian Shepherd Dog is a large and powerful breed of dog from the Caucasus Mountains region. These dogs are large in size, with a thick double coat to protect them from the cold. They have a regal bearing, with a proud and confident demeanor. They are highly intelligent and loyal, making them excellent guard dogs. They are courageous and alert, with an instinct to protect their family and property. They are highly trainable, but require firm and consistent training.',
#     'life': {'max': 20, 'min': 15},
#     'male_weight': {'max': 90, 'min': 50},
#     'female_weight': {'max': 70, 'min': 45},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '8000793f-a1ae-4ec4-8d55-ef83f1f644e5',
#       'type': 'group'}}}},
#   {'id': '4ddbe251-72af-495e-8e9d-869217e1d92a',
#    'type': 'breed',
#    'attributes': {'name': 'Bouvier des Flandres',
#     'description': 'The Bouvier des Flandres is a large and powerful breed of dog from the Flanders region of Belgium. These dogs are very large in size, with a thick double coat of wire-haired fur. They have a dignified but energetic demeanor, making them excellent working dogs. They are highly intelligent and trainable, with an instinct to protect their family and property. They are brave and loyal, with an independent nature that makes them well suited for herding and guard work.',
#     'life': {'max': 14, 'min': 10},
#     'male_weight': {'max': 40, 'min': 30},
#     'female_weight': {'max': 35, 'min': 25},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': 'b8e4e89d-057f-432a-9e58-0b85b29b693c',
#       'type': 'group'}}}},
#   {'id': 'f534c847-bed1-4b58-b194-dc06ecfe20f9',
#    'type': 'breed',
#    'attributes': {'name': 'Grand Basset Griffon Vendéen',
#     'description': 'The Grand Basset Griffon Vendéen is a medium-sized breed of scent hound from the Vendéen region of France. These dogs are medium in size, with a long and wiry coat of fur. They have an energetic and cheerful demeanor, with an instinct for hunting and tracking. They are highly trainable and intelligent, but require firm and consistent training to be obedient. They are loyal and devoted to their family, but can be stubborn and independent at times.',
#     'life': {'max': 15, 'min': 12},
#     'male_weight': {'max': 30, 'min': 20},
#     'female_weight': {'max': 30, 'min': 20},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': 'be0147df-7755-4228-b132-2518c0c6d10d',
#       'type': 'group'}}}},
#   {'id': '30f62219-e225-42cd-bd07-02425f944c07',
#    'type': 'breed',
#    'attributes': {'name': 'Hokkaido',
#     'description': 'The Hokkaido is a medium-sized breed of dog from the island of Hokkaido in Japan. These dogs are medium in size, with a thick double coat of fur to protect them from the cold. They have a dignified and loyal demeanor, making them excellent guard and companion dogs. They are intelligent and trainable, but require firm and consistent training to be obedient. They are brave and alert, with an instinct to protect their family and property.',
#     'life': {'max': 15, 'min': 12},
#     'male_weight': {'max': 30, 'min': 20},
#     'female_weight': {'max': 30, 'min': 20},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '8000793f-a1ae-4ec4-8d55-ef83f1f644e5',
#       'type': 'group'}}}},
#   {'id': '087979f3-1c45-4d8a-a153-462bf5ea379e',
#    'type': 'breed',
#    'attributes': {'name': 'Japanese Terrier',
#     'description': 'The Japanese Terrier is a small breed of terrier from Japan. These dogs are small in size, with a short and wiry coat of fur. They have a lively and energetic demeanor, with an instinct for hunting. They are highly intelligent and trainable, but require firm and consistent training to be obedient. They are loyal and devoted to their family, with an independent nature that makes them well suited for herding and guard work.',
#     'life': {'max': 20, 'min': 15},
#     'male_weight': {'max': 4, 'min': 2},
#     'female_weight': {'max': 4, 'min': 2},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '8000793f-a1ae-4ec4-8d55-ef83f1f644e5',
#       'type': 'group'}}}},
#   {'id': 'dbff689b-8370-4b6a-9306-215aba549102',
#    'type': 'breed',
#    'attributes': {'name': 'Hanoverian Scenthound',
#     'description': 'The Hanoverian Scenthound is a medium-sized breed of scent hound from the Hanover region of Germany. These dogs are medium in size, with a short and wiry coat of fur. They have a friendly and energetic demeanor, with an instinct for hunting and tracking. They are highly intelligent and trainable, but require firm and consistent training to be obedient. They are loyal and devoted to their family, but can be stubborn and independent at times.',
#     'life': {'max': 14, 'min': 12},
#     'male_weight': {'max': 25, 'min': 20},
#     'female_weight': {'max': 25, 'min': 20},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '8000793f-a1ae-4ec4-8d55-ef83f1f644e5',
#       'type': 'group'}}}},
#   {'id': '6f540c30-27a8-48cc-8d88-0b1d9fa99167',
#    'type': 'breed',
#    'attributes': {'name': 'Tibetan Spaniel',
#     'description': 'The Tibetan Spaniel is a small breed of spaniel from Tibet. These dogs are small in size, with a short and silky coat of fur. They have a cheerful and affectionate demeanor, making them excellent companion dogs. They are highly trainable and intelligent, with an instinct to protect their family and property. They are loyal and devoted to their family, but can be stubborn and independent at times.',
#     'life': {'max': 16, 'min': 14},
#     'male_weight': {'max': 7, 'min': 5},
#     'female_weight': {'max': 7, 'min': 5},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '7f6ea988-366a-4e20-b4ba-4d04274fea61',
#       'type': 'group'}}}},
#   {'id': '20b1d8be-ae44-4a70-8526-0612904bc9b2',
#    'type': 'breed',
#    'attributes': {'name': 'Border Collie',
#     'description': 'The Border Collie is a medium-sized breed of herding dog from the borders of England and Scotland. These dogs are medium in size, with a thick double coat of fur to protect them from the cold. They have an energetic and intelligent demeanor, with an instinct for herding and working. They are highly trainable and obedient, but require firm and consistent training to be obedient. They are loyal and devoted to their family, with an independent nature that makes them well suited for herding and guard work.',
#     'life': {'max': 16, 'min': 12},
#     'male_weight': {'max': 30, 'min': 20},
#     'female_weight': {'max': 25, 'min': 17},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': 'b8e4e89d-057f-432a-9e58-0b85b29b693c',
#       'type': 'group'}}}},
#   {'id': '6dee41b1-0805-4f4e-a079-c8b1cdfa1768',
#    'type': 'breed',
#    'attributes': {'name': 'Curly-Coated Retriever',
#     'description': 'The Curly-Coated Retriever is a large breed of retrieving dog from England. These dogs are large in size, with a curly coat of fur. They have a dignified and energetic demeanor, making them excellent working dogs. They are highly intelligent and trainable, with an instinct to retrieve game. They are loyal and devoted to their family, with an independent nature that makes them well suited for retrieving and guard work.',
#     'life': {'max': 14, 'min': 12},
#     'male_weight': {'max': 34, 'min': 27},
#     'female_weight': {'max': 32, 'min': 25},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': 'ab110192-e41b-43ff-a630-f7aee156b33a',
#       'type': 'group'}}}},
#   {'id': 'beff84c3-66c4-4335-beba-f346c2565881',
#    'type': 'breed',
#    'attributes': {'name': 'Skye Terrier',
#     'description': 'The Skye Terrier is a small breed of terrier from the Isle of Skye in Scotland. These dogs are small in size, with a long and wiry coat of fur. They have a dignified and independent demeanor, with an instinct for hunting. They are highly intelligent and trainable, but require firm and consistent training to be obedient. They are loyal and devoted to their family, but can be stubborn and independent at times.',
#     'life': {'max': 15, 'min': 12},
#     'male_weight': {'max': 8, 'min': 7},
#     'female_weight': {'max': 8, 'min': 7},
#     'hypoallergenic': False},
#    'relationships': {'group': {'data': {'id': '1bbf373b-1937-4e73-9863-45385daa4979',
#       'type': 'group'}}}}],
#  'links': {'self': 'https://dogapi.dog/api/v2/breeds',
#   'current': 'https://dogapi.dog/api/v2/breeds?page[number]=1',
#   'next': 'https://dogapi.dog/api/v2/breeds?page[number]=2',
#   'last': 'https://dogapi.dog/api/v2/breeds?page[number]=29'}}

# %%
res["links"]
# Out:
# {'self': 'https://dogapi.dog/api/v2/breeds',
#  'current': 'https://dogapi.dog/api/v2/breeds?page[number]=1',
#  'next': 'https://dogapi.dog/api/v2/breeds?page[number]=2',
#  'last': 'https://dogapi.dog/api/v2/breeds?page[number]=29'}

# %%
res["data"][2]["attributes"]["name"]
# Out:
# 'Grand Basset Griffon Vendéen'

# %%
list_of_breeds = [breed["attributes"]["name"] for breed in res["data"]]
list_of_breeds
# Out:
# ['Caucasian Shepherd Dog',
#  'Bouvier des Flandres',
#  'Grand Basset Griffon Vendéen',
#  'Hokkaido',
#  'Japanese Terrier',
#  'Hanoverian Scenthound',
#  'Tibetan Spaniel',
#  'Border Collie',
#  'Curly-Coated Retriever',
#  'Skye Terrier']

# %%
# Antonio
res = requests.get("https://xeno-canto.org/api/2/recordings?query=cnt:brazil").json()
res["recordings"]
# Out:
# [{'id': '754598',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'male',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754598',
#   'file': 'https://xeno-canto.org/754598/download',
#   'file-name': 'XC754598-18-09-2022-8e21-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754598-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754598-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754598-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754598-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:20',
#   'time': '8:21',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': ['Tangara chilensis'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '695999',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Felipe Arantes',
#   'cnt': 'Brazil',
#   'loc': 'Vitória do Xingu, Pará',
#   'lat': '-3.3389',
#   'lng': '-51.8571',
#   'alt': '130',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/695999',
#   'file': 'https://xeno-canto.org/695999/download',
#   'file-name': 'XC695999-STE-037 Pyriglena similis.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/ffts/XC695999-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/ffts/XC695999-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/ffts/XC695999-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/ffts/XC695999-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/wave/XC695999-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/wave/XC695999-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/AKHCFQUKLZ/wave/XC695999-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:34',
#   'time': '08:00',
#   'date': '2021-11-07',
#   'uploaded': '2022-01-07',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '529078',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Benedito Pio da Silva Campos Neto',
#   'cnt': 'Brazil',
#   'loc': 'Chapada dos Guimarães, Mato Grosso. Cond. Manauá',
#   'lat': '-15.4467',
#   'lng': '-55.7002',
#   'alt': '750',
#   'type': 'song',
#   'sex': 'female',
#   'stage': 'adult',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/529078',
#   'file': 'https://xeno-canto.org/529078/download',
#   'file-name': 'XC529078-papa.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/ffts/XC529078-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/ffts/XC529078-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/ffts/XC529078-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/ffts/XC529078-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/wave/XC529078-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/wave/XC529078-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/YKEVZTXLJM/wave/XC529078-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:25',
#   'time': '10:30',
#   'date': '2020-02-17',
#   'uploaded': '2020-02-22',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '246018',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': 'maura',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Comodoro, Mato Grosso',
#   'lat': '-13.3001',
#   'lng': '-59.8001',
#   'alt': '550',
#   'type': 'call, song, various different calls',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/246018',
#   'file': 'https://xeno-canto.org/246018/download',
#   'file-name': 'XC246018-PYRLNT13.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246018-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246018-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246018-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246018-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246018-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246018-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246018-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '1:53',
#   'time': '07:34',
#   'date': '2003-04-02',
#   'uploaded': '2015-05-25',
#   'also': ['Thamnophilus stictocephalus'],
#   'rmk': 'Campinarana',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '214239',
#   'gen': 'Saltator',
#   'sp': 'olivascens',
#   'ssp': 'olivascens',
#   'group': 'birds',
#   'en': 'Olivaceous Saltator',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Boa Vista. Ilha São José',
#   'lat': '2.9501',
#   'lng': '-60.5167',
#   'alt': '70',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/214239',
#   'file': 'https://xeno-canto.org/214239/download',
#   'file-name': 'XC214239-SALCOE12.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC214239-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC214239-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC214239-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC214239-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC214239-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC214239-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC214239-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:55',
#   'time': '07:50',
#   'date': '2001-07-11',
#   'uploaded': '2015-02-21',
#   'also': ['Sakesphorus canadensis'],
#   'rmk': 'natural song of single bird in tree 25m from mic',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '178515',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Douglas Meyer',
#   'cnt': 'Brazil',
#   'loc': 'Rosário Oeste, Mato Grosso',
#   'lat': '-14.8264',
#   'lng': '-56.4241',
#   'alt': '200',
#   'type': 'song',
#   'sex': 'female, male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/178515',
#   'file': 'https://xeno-canto.org/178515/download',
#   'file-name': 'XC178515-Thamnophilidae_Pyriglena_leuconota_05_08_2013_H08_14_Rosário_Oeste.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC178515-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC178515-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC178515-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC178515-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC178515-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC178515-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC178515-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:38',
#   'time': '08:14',
#   'date': '2013-08-05',
#   'uploaded': '2014-05-18',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '174050',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'João Antônio de B. Vitto',
#   'cnt': 'Brazil',
#   'loc': 'Rosário Oeste, Mato Grosso',
#   'lat': '-14.8264',
#   'lng': '-56.4241',
#   'alt': '200',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/174050',
#   'file': 'https://xeno-canto.org/174050/download',
#   'file-name': 'XC174050-PAPA TAOCA - ROSARIO OESTE - 05-08-13 (1).mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/ffts/XC174050-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/ffts/XC174050-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/ffts/XC174050-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/ffts/XC174050-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/wave/XC174050-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/wave/XC174050-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/RIVNLYTULO/wave/XC174050-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:38',
#   'time': '09:00',
#   'date': '2013-08-05',
#   'uploaded': '2014-04-12',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '171181',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': 'maura',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'Jauru, Mato Grosso',
#   'lat': '-15.2102',
#   'lng': '-58.8885',
#   'alt': '500',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/171181',
#   'file': 'https://xeno-canto.org/171181/download',
#   'file-name': 'XC171181-Pyriglena leuconota_Jauru_1425.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171181-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171181-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171181-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171181-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171181-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171181-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171181-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'A',
#   'length': '0:40',
#   'time': '11:00',
#   'date': '2014-03-25',
#   'uploaded': '2014-03-26',
#   'also': ['Thamnophilus doliatus'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '108542',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Tayler Brooks',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '200',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/108542',
#   'file': 'https://xeno-canto.org/108542/download',
#   'file-name': 'White-backed Fire-eye song 8-19-11.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/ffts/XC108542-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/ffts/XC108542-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/ffts/XC108542-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/ffts/XC108542-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/wave/XC108542-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/wave/XC108542-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ARFGONJCBJ/wave/XC108542-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'A',
#   'length': '0:19',
#   'time': '15:20',
#   'date': '2011-08-19',
#   'uploaded': '2012-08-26',
#   'also': [],
#   'rmk': 'Natural vocalization. Near small antswarm.',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '89196',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': 'maura',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Vila Bela da Santíssima Trindade, MG. Fazenda Boa Esperança',
#   'lat': '-15.0178',
#   'lng': '-59.8826',
#   'alt': '200',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/89196',
#   'file': 'https://xeno-canto.org/89196/download',
#   'file-name': 'PYRLNT12.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89196-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89196-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89196-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89196-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89196-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89196-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89196-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'A',
#   'length': '0:28',
#   'time': '06:20',
#   'date': '2003-03-23',
#   'uploaded': '2011-10-27',
#   'also': ['Lipaugus vociferans'],
#   'rmk': 'Dry semideciduous forest. After playback.',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '80263',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': 'maura',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Corumbá, MS',
#   'lat': '-19.01',
#   'lng': '-57.6528',
#   'alt': '150',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/80263',
#   'file': 'https://xeno-canto.org/80263/download',
#   'file-name': 'PYRLNT04.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC80263-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC80263-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC80263-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC80263-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC80263-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC80263-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC80263-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'A',
#   'length': '0:21',
#   'time': '07:31',
#   'date': '2000-01-16',
#   'uploaded': '2011-06-07',
#   'also': ['Crypturellus undulatus'],
#   'rmk': 'Forest at foot of the Morro do Urucum. Two natural songs by a bird in thick undergrowth. Male seen after playback.',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '38467',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Andrew Spencer',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '250',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/38467',
#   'file': 'https://xeno-canto.org/38467/download',
#   'file-name': 'White-backed Fire-eye2009-8-23-1part1.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/ffts/XC38467-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/ffts/XC38467-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/ffts/XC38467-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/ffts/XC38467-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/wave/XC38467-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/wave/XC38467-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CDTGHVBGZP/wave/XC38467-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'A',
#   'length': '1:18',
#   'time': '07:25',
#   'date': '2009-08-23',
#   'uploaded': '2009-09-05',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '754583',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754583',
#   'file': 'https://xeno-canto.org/754583/download',
#   'file-name': 'XC754583-18-09-2022-8e13-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754583-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754583-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754583-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754583-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754583-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754583-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754583-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:12',
#   'time': '8:13',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': ['Myrmoborus myotherinus'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '754581',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754581',
#   'file': 'https://xeno-canto.org/754581/download',
#   'file-name': 'XC754581-18-09-2022-8e10-Papa-taoca-do-tapajos-e-formigueiro-de-cauda-baia-(Pyriglena-similis).mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754581-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754581-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754581-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754581-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754581-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754581-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754581-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:10',
#   'time': '8:10',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': ['Sciaphylax hemimelaena'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '754579',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754579',
#   'file': 'https://xeno-canto.org/754579/download',
#   'file-name': 'XC754579-18-09-2022-8e6-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754579-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754579-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754579-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754579-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754579-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754579-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754579-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:04',
#   'time': '8:06',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '708374',
#   'gen': 'Campylopterus',
#   'sp': 'diamantinensis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Diamantina Sabrewing',
#   'rec': 'Guilherme de Melo Becher',
#   'cnt': 'Brazil',
#   'loc': 'Trilha do Pico da Lapinha, Lapinha da Serra-MG, Minas Gerais',
#   'lat': '-19.1083',
#   'lng': '-43.6708',
#   'alt': '1430',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/708374',
#   'file': 'https://xeno-canto.org/708374/download',
#   'file-name': 'XC708374-MixPre-130 possivel C diamantinensis.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708374-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708374-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708374-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708374-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708374-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708374-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708374-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '1:12',
#   'time': '10:00',
#   'date': '2022-03-03',
#   'uploaded': '2022-03-14',
#   'also': [],
#   'rmk': 'não estou 100% seguro desta id, porém bate com chamados do grupo Campylopterus. Um indivíduo foi avistado, fotografado e gravado poucos minutos antes, verificar XC708373',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '580956',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Scott Olmstead',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, Mato Grosso',
#   'lat': '-9.5969',
#   'lng': '-55.9338',
#   'alt': '260',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/580956',
#   'file': 'https://xeno-canto.org/580956/download',
#   'file-name': 'XC580956-2006-06-08-White-backed Fire-eye song-SOlmstead.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/ffts/XC580956-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/ffts/XC580956-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/ffts/XC580956-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/ffts/XC580956-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/wave/XC580956-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/wave/XC580956-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DABODLPUPA/wave/XC580956-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:25',
#   'time': '?',
#   'date': '2006-06-08',
#   'uploaded': '2020-08-05',
#   'also': ['Rhegmatorhina gymnops'],
#   'rmk': 'At antswarm.',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '385745',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Tulio Dornas',
#   'cnt': 'Brazil',
#   'loc': 'ribeirão chiqueirão, Rosário Oeste, Mato Grosso',
#   'lat': '-15.1274',
#   'lng': '-56.6437',
#   'alt': '220',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/385745',
#   'file': 'https://xeno-canto.org/385745/download',
#   'file-name': 'XC385745-Pyriglena_leuconota_Basileuterus_hypoleucus_Dromococcyx_phasianellus_M6_Trans_2-3_Jangada_MT.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/ffts/XC385745-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/ffts/XC385745-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/ffts/XC385745-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/ffts/XC385745-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/wave/XC385745-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/wave/XC385745-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MTUQGBMRNC/wave/XC385745-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:44',
#   'time': '06:30',
#   'date': '2013-07-04',
#   'uploaded': '2017-09-09',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '333327',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Comodoro, Mato Grosso',
#   'lat': '-13.3001',
#   'lng': '-59.8001',
#   'alt': '550',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/333327',
#   'file': 'https://xeno-canto.org/333327/download',
#   'file-name': 'XC333327-UNID0478.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC333327-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC333327-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC333327-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC333327-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC333327-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC333327-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC333327-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:33',
#   'time': '07:28',
#   'date': '2003-04-02',
#   'uploaded': '2016-09-05',
#   'also': ['Machaeropterus pyrocephalus'],
#   'rmk': 'campinarana',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '246020',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '260',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/246020',
#   'file': 'https://xeno-canto.org/246020/download',
#   'file-name': 'XC246020-PYRLNT05.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246020-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246020-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246020-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC246020-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246020-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246020-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC246020-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:48',
#   'time': '16:05',
#   'date': '2000-09-15',
#   'uploaded': '2015-05-25',
#   'also': ['Ramphastos tucanus', 'Lipaugus vociferans'],
#   'rmk': 'terra firme forest - natural and after playback',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '171180',
#   'gen': 'Pyriglena',
#   'sp': 'maura',
#   'ssp': 'maura',
#   'group': 'birds',
#   'en': 'Western Fire-eye',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'Jauru, Mato Grosso',
#   'lat': '-15.2102',
#   'lng': '-58.8885',
#   'alt': '500',
#   'type': 'call',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/171180',
#   'file': 'https://xeno-canto.org/171180/download',
#   'file-name': 'XC171180-Piryglena leuconota_Jauru_1424.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171180-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171180-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171180-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC171180-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171180-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171180-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC171180-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'B',
#   'length': '0:44',
#   'time': '11:00',
#   'date': '2014-03-25',
#   'uploaded': '2014-03-26',
#   'also': ['Thamnophilus doliatus'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '169430',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Micah Riegner',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '260',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/169430',
#   'file': 'https://xeno-canto.org/169430/download',
#   'file-name': 'XC169430-9991290.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/ffts/XC169430-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/ffts/XC169430-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/ffts/XC169430-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/ffts/XC169430-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/wave/XC169430-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/wave/XC169430-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TXYAPFWGKB/wave/XC169430-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '0:51',
#   'time': '06:30',
#   'date': '2013-09-10',
#   'uploaded': '2014-03-10',
#   'also': [],
#   'rmk': 'Calling 1 meter off the ground in Guadua Bamboo.',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '147427',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'Itaituba, Para',
#   'lat': '-5.4957',
#   'lng': '-56.9861',
#   'alt': '150',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/147427',
#   'file': 'https://xeno-canto.org/147427/download',
#   'file-name': 'XC147427-Pyriglena leuconota_Itaituba_1103.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC147427-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC147427-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC147427-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC147427-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC147427-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC147427-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC147427-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '0:25',
#   'time': '09:30',
#   'date': '2013-08-23',
#   'uploaded': '2013-09-13',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '130291',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Eric DeFonso',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '260',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/130291',
#   'file': 'https://xeno-canto.org/130291/download',
#   'file-name': 'XC130291-20110928-0745-1195-BR-MT-Cristalino Reserve-White-backed Fire-eye.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC130291-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC130291-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC130291-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC130291-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC130291-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC130291-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC130291-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '1:53',
#   'time': '07:45',
#   'date': '2011-09-28',
#   'uploaded': '2013-04-19',
#   'also': [],
#   'rmk': 'Extended cut of somewhat distant, unseen bird along the Taboca trail, singing in undergrowth in terra firme forest.',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '129851',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Eric DeFonso',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '260',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/129851',
#   'file': 'https://xeno-canto.org/129851/download',
#   'file-name': 'XC129851-20110920-0630-1088-BR-MT-Cristalino Reserve-White-backed Fire-eye.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC129851-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC129851-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC129851-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC129851-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC129851-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC129851-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC129851-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '1:53',
#   'time': '06:30',
#   'date': '2011-09-20',
#   'uploaded': '2013-04-17',
#   'also': ['Cercomacra cinerascens',
#    'Ceratopipra rubrocapilla',
#    'Cymbilaimus lineatus'],
#   'rmk': 'Extended cut of song from a mobile bird (~15m). Recorded along the trail to the new 50m tower in terra firme forest.',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '119198',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'Itaituba, Para',
#   'lat': '-5.8483',
#   'lng': '-55.8298',
#   'alt': '180',
#   'type': 'song',
#   'sex': 'male',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/119198',
#   'file': 'https://xeno-canto.org/119198/download',
#   'file-name': 'XC119198-Pyriglena leuconota_Itaituba.MP3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119198-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119198-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119198-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119198-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119198-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119198-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119198-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'B',
#   'length': '0:09',
#   'time': '11:00',
#   'date': '2011-12-03',
#   'uploaded': '2013-01-22',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '89192',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Jeremy Minns',
#   'cnt': 'Brazil',
#   'loc': 'Pousada Thaimaçu. Rio Cururu',
#   'lat': '-8.9167',
#   'lng': '-56.6667',
#   'alt': '250',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/89192',
#   'file': 'https://xeno-canto.org/89192/download',
#   'file-name': 'UNID0484.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89192-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89192-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89192-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/ffts/XC89192-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89192-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89192-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/DGVLLRYDXS/wave/XC89192-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/2.5/',
#   'q': 'B',
#   'length': '0:31',
#   'time': '15:58',
#   'date': '2003-04-12',
#   'uploaded': '2011-10-27',
#   'also': [],
#   'rmk': 'Terra firme forest. Two different calls, after playback.',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '69352',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'Frank Lambert',
#   'cnt': 'Brazil',
#   'loc': 'Cristalino Jungle Lodge, MT',
#   'lat': '-9.5981',
#   'lng': '-55.932',
#   'alt': '240',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/69352',
#   'file': 'https://xeno-canto.org/69352/download',
#   'file-name': 'Pyriglena_leuconota_2004a-FRL_BR_13_1556-1612_1_C.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/ffts/XC69352-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/ffts/XC69352-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/ffts/XC69352-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/ffts/XC69352-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/wave/XC69352-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/wave/XC69352-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/YTUXOCTUEM/wave/XC69352-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/',
#   'q': 'B',
#   'length': '0:44',
#   'time': '?:?',
#   'date': '2004-05-08',
#   'uploaded': '2011-01-07',
#   'also': [],
#   'rmk': 'Previously published on AVoCet as <a href=http://avocet.zoology.msu.edu/recordings/10159>AV10159</a>.  Certainty: 100%.  ID determined by: seen. GPS: Google Earth. several types',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '754618',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'female',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754618',
#   'file': 'https://xeno-canto.org/754618/download',
#   'file-name': 'XC754618-18-09-2022-9e10-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754618-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754618-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754618-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754618-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754618-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754618-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754618-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:49',
#   'time': '9:10',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': ['Ramphastos tucanus'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '754608',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754608',
#   'file': 'https://xeno-canto.org/754608/download',
#   'file-name': 'XC754608-18-09-2022-8e52-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754608-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754608-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754608-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754608-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754608-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754608-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754608-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:37',
#   'time': '8:52',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '754572',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
#   'rec': 'JAYRSON ARAUJO DE OLIVEIRA',
#   'cnt': 'Brazil',
#   'loc': 'Sinop, Cascalheiras - Mato Grosso',
#   'lat': '-11.7519',
#   'lng': '-55.638',
#   'alt': '340',
#   'type': 'song',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'in the hand',
#   'url': '//xeno-canto.org/754572',
#   'file': 'https://xeno-canto.org/754572/download',
#   'file-name': 'XC754572-18-09-2022-7e32-Papa-taoca-do-tapajos.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754572-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754572-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754572-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/ffts/XC754572-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754572-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754572-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/LXKLWEDKEM/wave/XC754572-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:47',
#   'time': '7:32',
#   'date': '2022-09-18',
#   'uploaded': '2022-10-08',
#   'also': ['Lepidocolaptes fuscicapillus',
#    'Machaeropterus pyrocephalus',
#    'Loriotus cristatus'],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': 'Panasonic RRUS551',
#   'mic': 'Embutido',
#   'smp': '44100'},
#  {'id': '708373',
#   'gen': 'Campylopterus',
#   'sp': 'diamantinensis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Diamantina Sabrewing',
#   'rec': 'Guilherme de Melo Becher',
#   'cnt': 'Brazil',
#   'loc': 'Trilha do Pico da Lapinha, Lapinha da Serra-MG, Minas Gerais',
#   'lat': '-19.1083',
#   'lng': '-43.6708',
#   'alt': '1430',
#   'type': 'flight call',
#   'sex': 'uncertain',
#   'stage': 'adult',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/708373',
#   'file': 'https://xeno-canto.org/708373/download',
#   'file-name': 'XC708373-MixPre-127 Campylopterus diamantinensis.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708373-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708373-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708373-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/ffts/XC708373-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708373-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708373-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/VWCBCAIJUC/wave/XC708373-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:07',
#   'time': '10:00',
#   'date': '2022-03-03',
#   'uploaded': '2022-03-14',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'yes',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '671404',
#   'gen': 'Pyriglena',
#   'sp': 'similis',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Tapajos Fire-eye',
# ...
#   'rec': 'Lari Boesing',
#   'cnt': 'Brazil',
#   'loc': 'Nazaré Paulista, São Paulo',
#   'lat': '-23.2452',
#   'lng': '-46.3323',
#   'alt': '1100',
#   'type': 'call, song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/389227',
#   'file': 'https://xeno-canto.org/389227/download',
#   'file-name': 'XC389227-140914_16_Cryp_obsoletus_Set14_16e50.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/ffts/XC389227-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/ffts/XC389227-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/ffts/XC389227-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/ffts/XC389227-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/wave/XC389227-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/wave/XC389227-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/ETMICIBVME/wave/XC389227-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:52',
#   'time': '17:00',
#   'date': '2014-09-14',
#   'uploaded': '2017-10-10',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '283086',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': 'obsoletus',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Ricardo José Mitidieri',
#   'cnt': 'Brazil',
#   'loc': 'Rio Bonito de Baixo - Nova Friburgo - RJ',
#   'lat': '-22.3926',
#   'lng': '-42.3662',
#   'alt': '850',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/283086',
#   'file': 'https://xeno-canto.org/283086/download',
#   'file-name': 'XC283086-inhambuguaçu.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC283086-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC283086-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC283086-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC283086-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC283086-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC283086-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC283086-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:57',
#   'time': '07:00',
#   'date': '2015-09-20',
#   'uploaded': '2015-09-29',
#   'also': ['Basileuterus culicivorus'],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '242616',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Eric DeFonso',
#   'cnt': 'Brazil',
#   'loc': '4x4 Trail, Reserva Ecológica de Guapiaçu, RJ',
#   'lat': '-22.4228',
#   'lng': '-42.7551',
#   'alt': '190',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/242616',
#   'file': 'https://xeno-canto.org/242616/download',
#   'file-name': 'XC242616-20140908-0823-BR0211-BR-RJ-REGUA-Brown Tinamou song filt amp.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC242616-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC242616-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC242616-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/ffts/XC242616-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC242616-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC242616-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/KTLCZCRCQX/wave/XC242616-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:11',
#   'time': '08:23',
#   'date': '2014-09-08',
#   'uploaded': '2015-05-15',
#   'also': [],
#   'rmk': 'Fragments of song from birds on steep forested hillsides.',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '221870',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Peter Boesman',
#   'cnt': 'Brazil',
#   'loc': 'Itapoá - Volta Velha, Santa Catarina',
#   'lat': '-26.1166666667',
#   'lng': '-48.5833333333',
#   'alt': '',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/221870',
#   'file': 'https://xeno-canto.org/221870/download',
#   'file-name': 'XC221870-Brown Tinamou C 137.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/ffts/XC221870-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/ffts/XC221870-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/ffts/XC221870-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/ffts/XC221870-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/wave/XC221870-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/wave/XC221870-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/OOECIWCSWV/wave/XC221870-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/',
#   'q': 'C',
#   'length': '0:29',
#   'time': '18:00',
#   'date': '2004-08-09',
#   'uploaded': '2015-03-22',
#   'also': [],
#   'rmk': 'ID certainty 100%. (Archiv. tape 333 side B track 47 seq. A)',
#   'bird-seen': 'unknown',
#   'animal-seen': 'unknown',
#   'playback-used': 'unknown',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '187442',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Marcos Melo',
#   'cnt': 'Brazil',
#   'loc': 'APA Capivari Monos, São Paulo, SP',
#   'lat': '-23.9557',
#   'lng': '-46.6503',
#   'alt': '760',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/187442',
#   'file': 'https://xeno-canto.org/187442/download',
#   'file-name': 'XC187442-Crypturellus obsoletu 16 11 08.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/ffts/XC187442-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/ffts/XC187442-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/ffts/XC187442-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/ffts/XC187442-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/wave/XC187442-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/wave/XC187442-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MRGDYNJGUJ/wave/XC187442-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:21',
#   'time': '07:30',
#   'date': '2008-11-16',
#   'uploaded': '2014-07-16',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '22050'},
#  {'id': '186796',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'João Gava',
#   'cnt': 'Brazil',
#   'loc': 'Passo Fundo, Rio Grande do Sul',
#   'lat': '-28.2147',
#   'lng': '-52.4067',
#   'alt': '650',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/186796',
#   'file': 'https://xeno-canto.org/186796/download',
#   'file-name': 'XC186796-Crypturellus_obsoletus_07_11_2013_Campus_Embrapa.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/ffts/XC186796-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/ffts/XC186796-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/ffts/XC186796-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/ffts/XC186796-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/wave/XC186796-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/wave/XC186796-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CEKMJEZKSJ/wave/XC186796-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:09',
#   'time': '10:00',
#   'date': '2013-11-07',
#   'uploaded': '2014-07-14',
#   'also': ['Leptotila verreauxi'],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '174640',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Douglas Meyer',
#   'cnt': 'Brazil',
#   'loc': 'Campo Belo do Sul, Santa Catarina',
#   'lat': '-28.0068',
#   'lng': '-50.8742',
#   'alt': '900',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/174640',
#   'file': 'https://xeno-canto.org/174640/download',
#   'file-name': 'XC174640-Crypturellus_obsoletus_17_06_2011_H08_29_Florestal_Gateados_Campo_Belo_do_Sul_SC.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC174640-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC174640-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC174640-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/ffts/XC174640-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC174640-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC174640-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/MNENFHYTAE/wave/XC174640-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '2:20',
#   'time': '08:29',
#   'date': '2011-06-17',
#   'uploaded': '2014-04-15',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '172799',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': 'obsoletus',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Ricardo José Mitidieri',
#   'cnt': 'Brazil',
#   'loc': 'Rio Bonito de Baixo - Nova Friburgo - RJ',
#   'lat': '-22.3926',
#   'lng': '-42.3662',
#   'alt': '850',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/172799',
#   'file': 'https://xeno-canto.org/172799/download',
#   'file-name': 'XC172799-inhambuguaçu 2013-12-01 sítio.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC172799-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC172799-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC172799-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/ffts/XC172799-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC172799-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC172799-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/CFRYARSVHN/wave/XC172799-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/4.0/',
#   'q': 'C',
#   'length': '0:39',
#   'time': '10:30',
#   'date': '2013-12-01',
#   'uploaded': '2014-04-07',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '11025'},
#  {'id': '151873',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'Rio Branco, Acre',
#   'lat': '-9.9147',
#   'lng': '-68.3446',
#   'alt': '220',
#   'type': 'call',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/151873',
#   'file': 'https://xeno-canto.org/151873/download',
#   'file-name': 'XC151873-Crypturellus obsoletus_Rio Branco_1214.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC151873-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC151873-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC151873-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC151873-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC151873-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC151873-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC151873-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '1:44',
#   'time': '13:00',
#   'date': '2013-10-13',
#   'uploaded': '2013-10-18',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '48000'},
#  {'id': '144627',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'Antonio Silveira',
#   'cnt': 'Brazil',
#   'loc': 'Serra do Mar State Park. Cunha',
#   'lat': '-23.267',
#   'lng': '-45.028',
#   'alt': '1100',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/144627',
#   'file': 'https://xeno-canto.org/144627/download',
#   'file-name': 'XC144627-Crypturellus obsoletus-NcCunha-PESM-Brazil-1-10-04-ASilveira.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/ffts/XC144627-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/ffts/XC144627-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/ffts/XC144627-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/ffts/XC144627-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/wave/XC144627-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/wave/XC144627-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/NBJQSQJRYH/wave/XC144627-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '0:20',
#   'time': '09:00',
#   'date': '2004-10-01',
#   'uploaded': '2013-08-10',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'no',
#   'animal-seen': 'no',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'},
#  {'id': '119062',
#   'gen': 'Crypturellus',
#   'sp': 'obsoletus',
#   'ssp': '',
#   'group': 'birds',
#   'en': 'Brown Tinamou',
#   'rec': 'GABRIEL LEITE',
#   'cnt': 'Brazil',
#   'loc': 'São José dos Campos, São Paulo',
#   'lat': '-23.0726',
#   'lng': '-45.9388',
#   'alt': '700',
#   'type': 'song',
#   'sex': '',
#   'stage': '',
#   'method': 'field recording',
#   'url': '//xeno-canto.org/119062',
#   'file': 'https://xeno-canto.org/119062/download',
#   'file-name': 'XC119062-Crypturellus obsoletus_Sao Jose.mp3',
#   'sono': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119062-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119062-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119062-large.png',
#    'full': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/ffts/XC119062-full.png'},
#   'osci': {'small': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119062-small.png',
#    'med': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119062-med.png',
#    'large': '//xeno-canto.org/sounds/uploaded/TGBFXDVERJ/wave/XC119062-large.png'},
#   'lic': '//creativecommons.org/licenses/by-nc-sa/3.0/',
#   'q': 'C',
#   'length': '0:31',
#   'time': '10:00',
#   'date': '2011-06-26',
#   'uploaded': '2013-01-22',
#   'also': [],
#   'rmk': '',
#   'bird-seen': 'yes',
#   'animal-seen': 'yes',
#   'playback-used': 'no',
#   'temp': '',
#   'regnr': '',
#   'auto': 'no',
#   'dvc': '',
#   'mic': '',
#   'smp': '44100'}]

# %%
res["recordings"][0]["gen"]
# Out:
# 'Pyriglena'

# %%
set_of_genres = {genre["gen"] for genre in res["recordings"]}
set_of_genres
# Out:
# {'Campylopterus', 'Crypturellus', 'Pyriglena', 'Rhea', 'Saltator', 'Tinamus'}

# %%
def get_lyrics (artist, song):
    print(requests.get(f"https://api.lyrics.ovh/v1/{artist}/{song}").json()["lyrics"])

get_lyrics("rihanna", "diamonds")
# Out:
# Paroles de la chanson Diamonds par Rihanna
# Shine bright like a diamond
# Shine bright like a diamond
#
# Find light in the beautiful sea
# I choose to be happy
# You and I, you and I, we're like diamonds in the sky
# You're a shooting star I see, a vision of ecstasy
# When you hold me, I'm alive, we're like diamonds in the sky
#
# I knew that we'd become one right away
# Oh, right away
# At first sight, I felt the energy of sun rays
# I saw the life inside your eyes
#
#
# So shine bright, tonight, you and I
# We're beautiful, like diamonds in the sky
# Eye to eye, so alive
# We're beautiful, like diamonds in the sky
#
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
# Shinin' bright like a diamond
# We're beautiful, like diamonds in the sky
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
# Shinin' bright like a diamond
# We're beautiful, like diamonds in the sky
#
# Palms rise to the universe as we moonshine and molly
# Feel the warmth, we'll never die
# We're like diamonds in the sky
#
# You're a shooting star I see, a vision of ecstasy
# When you hold me, I'm alive
# We're like diamonds in the sky
#
# At first sight, I felt the energy of sun rays
# I saw the life inside your eyes
#
# So shine bright, tonight, you and I
# We're beautiful, like diamonds in the sky
# Eye to eye, so alive
# We're beautiful, like diamonds in the sky
#
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
# Shinin' bright like a diamond
# We're beautiful, like diamonds in the sky
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
#
# Shinin' bright like a diamond
# We're beautiful, like diamonds in the sky
#
# Shine bright like a diamond
# Shine bright like a diamond
# Shine bright like a diamond
#
# So shine bright, tonight, you and I
# We're beautiful, like diamonds in the sky
# Eye to eye, so alive
# We're beautiful, like diamonds in the sky
#
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
# Shine bright like a diamond
# Oh-oh, yeah
# Shine bright like a diamond (Woah)
# Shine bright like a diamond (Woah)
#
# Shine bright like a diamond
# Shine bright like a diamond

# %%
# Nico
import requests
import json
res = requests.get("https://www.balldontlie.io/api/v1/players").json()
res # last_name & city & full_name
# Out:
# {'data': [{'id': 149,
#    'first_name': 'Keenan',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Evans',
#    'position': 'G',
#    'team': {'id': 9,
#     'abbreviation': 'DET',
#     'city': 'Detroit',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Detroit Pistons',
#     'name': 'Pistons'},
#    'weight_pounds': None},
#   {'id': 1705,
#    'first_name': 'Maurice',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Ager',
#    'position': '',
#    'team': {'id': 7,
#     'abbreviation': 'DAL',
#     'city': 'Dallas',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Dallas Mavericks',
#     'name': 'Mavericks'},
#    'weight_pounds': None},
#   {'id': 382,
#    'first_name': 'Billy',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Preston',
#    'position': 'F',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': None},
#   {'id': 448,
#    'first_name': 'Gary',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Trent Jr.',
#    'position': 'G',
#    'team': {'id': 25,
#     'abbreviation': 'POR',
#     'city': 'Portland',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Portland Trail Blazers',
#     'name': 'Trail Blazers'},
#    'weight_pounds': None},
#   {'id': 941,
#    'first_name': 'Chris',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Carr',
#    'position': '',
#    'team': {'id': 18,
#     'abbreviation': 'MIN',
#     'city': 'Minnesota',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Minnesota Timberwolves',
#     'name': 'Timberwolves'},
#    'weight_pounds': None},
#   {'id': 2353,
#    'first_name': 'Kenny',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Carr',
#    'position': '',
#    'team': {'id': 25,
#     'abbreviation': 'POR',
#     'city': 'Portland',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Portland Trail Blazers',
#     'name': 'Trail Blazers'},
#    'weight_pounds': None},
#   {'id': 2258,
#    'first_name': 'M.L.',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Carr',
#    'position': '',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': None},
#   {'id': 2448,
#    'first_name': 'Bob',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Carrington',
#    'position': '',
#    'team': {'id': 3,
#     'abbreviation': 'BKN',
#     'city': 'Brooklyn',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Brooklyn Nets',
#     'name': 'Nets'},
#    'weight_pounds': None},
#   {'id': 84,
#    'first_name': 'DeMarre',
#    'height_feet': 6,
#    'height_inches': 8,
#    'last_name': 'Carroll',
#    'position': 'F',
#    'team': {'id': 1,
#     'abbreviation': 'ATL',
#     'city': 'Atlanta',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Atlanta Hawks',
#     'name': 'Hawks'},
#    'weight_pounds': 215},
#   {'id': 3077,
#    'first_name': 'Joe',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Barry,Carroll',
#    'position': '',
#    'team': {'id': 10,
#     'abbreviation': 'GSW',
#     'city': 'Golden State',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Golden State Warriors',
#     'name': 'Warriors'},
#    'weight_pounds': None},
#   {'id': 1504,
#    'first_name': 'Matt',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Carroll',
#    'position': '',
#    'team': {'id': 4,
#     'abbreviation': 'CHA',
#     'city': 'Charlotte',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Charlotte Hornets',
#     'name': 'Hornets'},
#    'weight_pounds': None},
#   {'id': 766,
#    'first_name': 'Robert',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Werdann',
#    'position': '',
#    'team': {'id': 8,
#     'abbreviation': 'DEN',
#     'city': 'Denver',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Denver Nuggets',
#     'name': 'Nuggets'},
#    'weight_pounds': None},
#   {'id': 962,
#    'first_name': 'Ed',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': "O'Bannon",
#    'position': '',
#    'team': {'id': 3,
#     'abbreviation': 'BKN',
#     'city': 'Brooklyn',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Brooklyn Nets',
#     'name': 'Nets'},
#    'weight_pounds': None},
#   {'id': 1003,
#    'first_name': 'John',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Coker',
#    'position': '',
#    'team': {'id': 24,
#     'abbreviation': 'PHX',
#     'city': 'Phoenix',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Phoenix Suns',
#     'name': 'Suns'},
#    'weight_pounds': None},
#   {'id': 1569,
#    'first_name': 'Tim',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Pickett',
#    'position': '',
#    'team': {'id': 19,
#     'abbreviation': 'NOP',
#     'city': 'New Orleans',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'New Orleans Pelicans',
#     'name': 'Pelicans'},
#    'weight_pounds': None},
#   {'id': 269,
#    'first_name': 'Jake',
#    'height_feet': 6,
#    'height_inches': 9,
#    'last_name': 'Layman',
#    'position': 'F',
#    'team': {'id': 2,
#     'abbreviation': 'BOS',
#     'city': 'Boston',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Boston Celtics',
#     'name': 'Celtics'},
#    'weight_pounds': 215},
#   {'id': 46405453,
#    'first_name': 'Dennis',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Layton',
#    'position': '',
#    'team': {'id': 24,
#     'abbreviation': 'PHX',
#     'city': 'Phoenix',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Phoenix Suns',
#     'name': 'Suns'},
#    'weight_pounds': None},
#   {'id': 277,
#    'first_name': 'Caris',
#    'height_feet': 6,
#    'height_inches': 7,
#    'last_name': 'LeVert',
#    'position': 'G',
#    'team': {'id': 6,
#     'abbreviation': 'CLE',
#     'city': 'Cleveland',
#     'conference': 'East',
#     'division': 'Central',
#     'full_name': 'Cleveland Cavaliers',
#     'name': 'Cavaliers'},
#    'weight_pounds': 204},
#   {'id': 46406999,
#    'first_name': 'Emanuel',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Leaks',
#    'position': '',
#    'team': {'id': 23,
#     'abbreviation': 'PHI',
#     'city': 'Philadelphia',
#     'conference': 'East',
#     'division': 'Atlantic',
#     'full_name': 'Philadelphia 76ers',
#     'name': '76ers'},
#    'weight_pounds': None},
#   {'id': 2456,
#    'first_name': 'Allen',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Leavell',
#    'position': '',
#    'team': {'id': 11,
#     'abbreviation': 'HOU',
#     'city': 'Houston',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Houston Rockets',
#     'name': 'Rockets'},
#    'weight_pounds': None},
#   {'id': 2842,
#    'first_name': 'Jeff',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Lebo',
#    'position': '',
#    'team': {'id': 27,
#     'abbreviation': 'SAS',
#     'city': 'San Antonio',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'San Antonio Spurs',
#     'name': 'Spurs'},
#    'weight_pounds': None},
#   {'id': 2918,
#    'first_name': 'Eric',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Leckner',
#    'position': '',
#    'team': {'id': 29,
#     'abbreviation': 'UTA',
#     'city': 'Utah',
#     'conference': 'West',
#     'division': 'Northwest',
#     'full_name': 'Utah Jazz',
#     'name': 'Jazz'},
#    'weight_pounds': None},
#   {'id': 666720,
#    'first_name': 'Jalen',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Lecque',
#    'position': 'G',
#    'team': {'id': 24,
#     'abbreviation': 'PHX',
#     'city': 'Phoenix',
#     'conference': 'West',
#     'division': 'Pacific',
#     'full_name': 'Phoenix Suns',
#     'name': 'Suns'},
#    'weight_pounds': None},
#   {'id': 2051,
#    'first_name': 'Ricky',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Ledo',
#    'position': '',
#    'team': {'id': 7,
#     'abbreviation': 'DAL',
#     'city': 'Dallas',
#     'conference': 'West',
#     'division': 'Southwest',
#     'full_name': 'Dallas Mavericks',
#     'name': 'Mavericks'},
#    'weight_pounds': None},
#   {'id': 2485,
#    'first_name': 'Butch',
#    'height_feet': None,
#    'height_inches': None,
#    'last_name': 'Lee',
#    'position': '',
#    'team': {'id': 1,
#     'abbreviation': 'ATL',
#     'city': 'Atlanta',
#     'conference': 'East',
#     'division': 'Southeast',
#     'full_name': 'Atlanta Hawks',
#     'name': 'Hawks'},
#    'weight_pounds': None}],
#  'meta': {'current_page': 1, 'next_page': 2, 'per_page': 25}}

# %%
res # last_name & city & full_name
last_name = res["data"][0]["last_name"]
team = res["data"][0]["team"]["full_name"]
city = res["data"][0]["team"]["city"]

dict_ = {
    "Player":last_name,
    "Team":team,
    "City": city
}

dict_
# Out:
# {'Player': 'Evans', 'Team': 'Detroit Pistons', 'City': 'Detroit'}

# %%
def transform_list (res):
    
    new_list = []
    for i in res["data"]:

        last_name = i["last_name"]
        team = i["team"]["full_name"]
        city = i["team"]["city"]

        dict_ = {
            "Player":last_name,
            "Team":team,
            "City": city
        }

    new_list.append(dict_)
    df = pd.DataFrame(new_list)

    return df

df.groupby("City").agg({"Team": "count"}).sort_values(by="Team", ascending=False).plot(kind="bar");

# %%
# Leo
# Public holidays for more than 90 countries:
rq = requests.get('https://date.nager.at/api/v3/PublicHolidays/2024/ES').json()
rq[1]
# Out:
# {'date': '2024-01-06',
#  'localName': 'Día de Reyes / Epifanía del Señor',
#  'name': 'Epiphany',
#  'countryCode': 'ES',
#  'fixed': True,
#  'global': True,
#  'counties': None,
#  'launchYear': None,
#  'types': ['Public']}

# %%
def holidays_by_country (year, country):
    
    rq = requests.get(f'https://date.nager.at/api/v3/PublicHolidays/{year}/{country}').json()
    
    date = rq[0]["date"]
    name = rq[0]["localName"]

    new_list = []
    for i in rq:
        dict_ = {}
        dict_["The date"] = i["date"]
        dict_["Name"] = i["localName"]

        new_list.append(dict_)

    return pd.DataFrame(new_list)

holidays_by_country (2020, "BR")
# Out:
#       The date                                  Name
# 0   2020-01-01            Confraternização Universal
# 1   2020-02-24                              Carnaval
# 2   2020-02-25                              Carnaval
# 3   2020-04-10                     Sexta-feira Santa
# 4   2020-04-12                     Domingo de Páscoa
# 5   2020-04-21                     Dia de Tiradentes
# 6   2020-05-01                    Dia do Trabalhador
# 7   2020-06-11                        Corpus Christi
# 8   2020-07-09  Revolução Constitucionalista de 1932
# 9   2020-09-07                  Dia da Independência
# 10  2020-10-12               Nossa Senhora Aparecida
# 11  2020-11-02                        Dia de Finados
# 12  2020-11-15              Proclamação da República
# 13  2020-12-25                                 Natal

# %%
holidays_by_country (2024, "DE")
# Out:
#       The date                       Name
# 0   2024-01-01                    Neujahr
# 1   2024-01-06        Heilige Drei Könige
# 2   2024-03-08  Internationaler Frauentag
# 3   2024-03-29                 Karfreitag
# 4   2024-03-31               Ostersonntag
# 5   2024-04-01                Ostermontag
# 6   2024-05-01             Tag der Arbeit
# 7   2024-05-09        Christi Himmelfahrt
# 8   2024-05-19             Pfingstsonntag
# 9   2024-05-20              Pfingstmontag
# 10  2024-05-30               Fronleichnam
# 11  2024-08-15          Mariä Himmelfahrt
# 12  2024-09-20              Weltkindertag
# 13  2024-10-03  Tag der Deutschen Einheit
# 14  2024-10-31            Reformationstag
# 15  2024-11-01              Allerheiligen
# 16  2024-11-20            Buß- und Bettag
# 17  2024-12-25       Erster Weihnachtstag
# 18  2024-12-26      Zweiter Weihnachtstag

# %% [markdown]
# ![Screenshot%202022-10-20%20at%2014.06.06.png](attachment:Screenshot%202022-10-20%20at%2014.06.06.png)

# %% [markdown]
# ## STEPS TO GET REPONSES
#
# 1. Look for an API if it exists
# 2. Read the docs that that person created: API reference / API Docs / Get started / Quickstart / ....
# 3. I get the URL for the API: different from website url, "api.something"
# 4. I can issue requests through Python to the API-url
#
#
# ## STEPS TO MANIPULATE THE RESPONSES
#
# 1. If request object -> pass res.json() _probably_
# 2. I have a dictionary -> Do I want to turn it into a df?
# 3. You MIGHT want to do `json_normalize(res.json())`

# %% [markdown]
# ## Headers

# %% [markdown]
# HTTP headers are an important part of the API request and response, as they represent the metadata associated with the API request and response. Headers carry information for:
#
# - Request and response body
# - Authorization of the request
# - Cache of the response
# - Response cookies

# %%
# headers & params sometime are interchanged

    # headers: meta-info
        # authenticating: Auth (token, which is a password)
        
    # params: what you want from the info -> kilometers vs miles
       # munich shoes / new balance

# %% [markdown]
# ## API Keys / tokens / private_keys
# Some of the APIs we use will require authentication.

# %%
# token is a password
    # password
        # bank: log-in (password)
        # another password: for jsut doing transfers (token)
        
        # 2FA

# %% [markdown]
# - https://github.com/settings/tokens
# - https://docs.github.com/es/rest/guides/getting-started-with-the-rest-api
# - https://pypi.org/project/python-dotenv/
# - https://docs.github.com/es/rest/reference/permissions-required-for-github-apps

# %%
#gh_token

# %%
# 1. Create .env
# 2. Include .env in our .gitignore
# 3. Include environment variables into .env
# 4. Import environment variables into notebooks
# 5. DO NOT INCLUDE PRINTS OF THE VARIABLES ON YOUR NOTEBOOKS

# %%
# github.com -> link to website
# api.github.com -> link to api

# %% [markdown]
# Philosophy of life : What I do for one element of the list I do for all of them in one iteration, so let's review the first element and then we'll see

# %% [markdown]
# `.env`

# %%
# token
    # built into the string
    # part of params / headers

# .env
    # file that saves the passwods
    
# .gitignore
    # the file that ignores .env
    
# access / load the token into memory
    
"""
    import os
    from dotenv import load_dotenv # pip install python-dotenv
    load_dotenv()
    
    token = os.getenv("MY_VARIABLE")
    
    # DO NOT PRINT TOKEN!!!!!

"""

# %% [markdown]
# ## API Clients

# %% [markdown]
# ### THIS IS FROM RAPIDAPI --> https://rapidapi.com/community/api/open-weather-map/

# %%
import requests

url = "https://airport-info.p.rapidapi.com/airport"

querystring = {"iata":"bcn"}

headers = {
"X-RapidAPI-Key": "NOT AGAIN",
"X-RapidAPI-Host": "airport-info.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)

# %%
response.json()

# %% [markdown]
# ### Insomnia

# %% [markdown]
# We see insomnia --> https://insomnia.rest/download

# %% [markdown]
# In insomnia we can save different apis to be able to call them with a click, I leave you screenshots

# %% [markdown]
# ![insomnia](../images/in_1.png)
# ![insomnia](../images/in_2.png)
# ![insomnia](../images/in_3.png)
# ![insomnia](../images/in_4.png)

# %% [markdown]
# ### Codes generated by insomnia

# %%
import requests

url = "https://api.chucknorris.io/jokes/random"

payload = ""
response = requests.request("GET", url, data=payload)

response.json()["value"]
# Out:
# 'Chuck Norris once roundhouse kicked a guy called Phil. Afterwards Phil became known as Empty.'

# %% [markdown]
# ## Spotify

# %%
# Sign up as a developer
# Create an app
# Credentials: id & token (spotify: two steps)
# Use your token to do requests to things

# %%
# ALWAYS: limit your quests to 1 until you're sure the code works
# time.sleep(4): to give enough time not to over request within a time frame
# IP adress: 
    # restart your router
    # cached: incognito mode
    # Your phone data for one second 
    # VPN

# %%
url = "https://api.spotify.com/v1/playlists"

# %%
# 1. Sign up as a developer -> client_id & client_secret
# 2. Create an app (projects): tokens will be linked to this app
# 3: Get credentials for authentication -> token for requests

# %% [markdown]
# ### Load initial credentials

# %% [markdown]
# ### Get token from those initial credentials

# %% [markdown]
# ### With token, we can create the headers

# %% [markdown]
# ## Summary

# %%
# tuesday morning
    # using an API / web scrapping
    # another dataset (kaggle)
    
    # describe / analysis
    # visualizations
    
    # evolution of sales
    # what are the most sold movies
        # information about the directors of the movies
    # sales of something
        # weather API

# %% [markdown]
# ## Further materials

# %% [markdown]
# - [5 Simple-To-Use APIs for Beginners](https://dev.to/alanconstantino/5-simple-to-use-apis-for-beginners-2e0n)
# - [RapidAPI](https://rapidapi.com/category/Sports): access thousands of APIs!!
# - [More APIs](https://github.com/public-apis/public-apis)
